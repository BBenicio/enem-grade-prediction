# %%
import os
import pandas as pd

# %%
pd.options.display.max_rows = 200
pd.options.display.max_columns = 200

# %%
data_folder = './data'
df = pd.read_csv(os.path.join(data_folder, 'test_intermediate.csv'), index_col=0)
print(df.shape)
df.head()
# Out:
# C:\Users\bruno\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (1783345, 104)
#   no_municipio_residencia sg_uf_residencia  nu_idade    tp_sexo  \
# 0                  Iguatu               CE      22.0   Feminino
# 1                  Santos               SP      19.0   Feminino
# 2                 Socorro               SP      16.0   Feminino
# 3            Praia Grande               SP      22.0  Masculino
# 4                Curitiba               PR      17.0  Masculino
#
#   tp_estado_civil tp_cor_raca tp_nacionalidade no_municipio_nascimento  \
# 0     Solteiro(a)       Parda    Brasileiro(a)                  Iguatu
# 1     Solteiro(a)      Branca    Brasileiro(a)                  Santos
# 2     Solteiro(a)      Branca    Brasileiro(a)                 Socorro
# 3     Solteiro(a)      Branca    Brasileiro(a)            Praia Grande
# 4     Solteiro(a)      Branca    Brasileiro(a)                Curitiba
#
#   sg_uf_nascimento                                    tp_st_conclusao  \
# 0               CE                          Já concluí o Ensino Médio
# 1               SP                          Já concluí o Ensino Médio
# 2               SP  Estou cursando e concluirei o Ensino Médio apó...
# 3               SP                          Já concluí o Ensino Médio
# 4               PR  Estou cursando e concluirei o Ensino Médio no ...
#
#   tp_ano_concluiu      tp_escola       tp_ensino in_treineiro  co_escola  \
# 0            2016  Não respondeu  Ensino Regular          Não        NaN
# 1            2018  Não respondeu  Ensino Regular          Não        NaN
# 2   Não informado  Não respondeu             NaN          Sim        NaN
# 3            2014  Não respondeu  Ensino Regular          Não        NaN
# 4   Não informado        Privada  Ensino Regular          Não        NaN
#
#   no_municipio_esc sg_uf_esc tp_dependencia_adm_esc tp_localizacao_esc  \
# 0              NaN       NaN                    NaN                NaN
# 1              NaN       NaN                    NaN                NaN
# 2              NaN       NaN                    NaN                NaN
# 3              NaN       NaN                    NaN                NaN
# 4              NaN       NaN                    NaN                NaN
#
#   tp_sit_func_esc in_baixa_visao in_cegueira in_surdez  \
# 0             NaN            Não         Não       Não
# 1             NaN            Não         Não       Não
# 2             NaN            Não         Não       Não
# 3             NaN            Não         Não       Não
# 4             NaN            Não         Não       Não
#
#   in_deficiencia_auditiva in_surdo_cegueira in_deficiencia_fisica  \
# 0                     Não               Não                   Não
# 1                     Não               Não                   Não
# 2                     Não               Não                   Não
# 3                     Não               Não                   Não
# 4                     Não               Não                   Não
#
#   in_deficiencia_mental in_deficit_atencao in_dislexia in_discalculia  \
# 0                   Não                Não         Não            Não
# 1                   Não                Não         Não            Não
# 2                   Não                Não         Não            Não
# 3                   Não                Não         Não            Não
# 4                   Não                Não         Não            Não
#
#   in_autismo in_visao_monocular in_outra_def in_gestante in_lactante in_idoso  \
# 0        Não                Não          Não         Não         Não      Não
# 1        Não                Não          Não         Não         Não      Não
# 2        Não                Não          Não         Não         Não      Não
# 3        Não                Não          Não         Não         Não      Não
# 4        Não                Não          Não         Não         Não      Não
#
#   in_estuda_classe_hospitalar in_sem_recurso in_braille in_ampliada_24  \
# 0                         Não            Não        Não            Não
# 1                         Não            Não        Não            Não
# 2                         Não            Não        Não            Não
# 3                         Não            Não        Não            Não
# 4                         Não            Não        Não            Não
#
#   in_ampliada_18 in_ledor in_acesso in_transcricao in_libras  \
# 0            Não      Não       Não            Não       Não
# 1            Não      Não       Não            Não       Não
# 2            Não      Não       Não            Não       Não
# 3            Não      Não       Não            Não       Não
# 4            Não      Não       Não            Não       Não
#
#   in_tempo_adicional in_leitura_labial in_mesa_cadeira_rodas  \
# 0                Não               Não                   Não
# 1                Não               Não                   Não
# 2                Não               Não                   Não
# 3                Não               Não                   Não
# 4                Não               Não                   Não
#
#   in_mesa_cadeira_separada in_apoio_perna in_guia_interprete in_computador  \
# 0                      Não            Não                Não           Não
# 1                      Não            Não                Não           Não
# 2                      Não            Não                Não           Não
# 3                      Não            Não                Não           Não
# 4                      Não            Não                Não           Não
#
#   in_cadeira_especial in_cadeira_canhoto in_cadeira_acolchoada  \
# 0                 Não                Não                   Não
# 1                 Não                Não                   Não
# 2                 Não                Não                   Não
# 3                 Não                Não                   Não
# 4                 Não                Não                   Não
#
#   in_prova_deitado in_mobiliario_obeso in_lamina_overlay  \
# 0              Não                 Não               Não
# 1              Não                 Não               Não
# 2              Não                 Não               Não
# 3              Não                 Não               Não
# 4              Não                 Não               Não
#
#   in_protetor_auricular in_medidor_glicose in_maquina_braile in_soroban  \
# 0                   Não                Não               Não        Não
# 1                   Não                Não               Não        Não
# 2                   Não                Não               Não        Não
# 3                   Não                Não               Não        Não
# 4                   Não                Não               Não        Não
#
#   in_marca_passo in_sonda in_medicamentos in_sala_individual in_sala_especial  \
# 0            Não      Não             Não                Não              Não
# 1            Não      Não             Não                Não              Não
# 2            Não      Não             Não                Não              Não
# 3            Não      Não             Não                Não              Não
# 4            Não      Não             Não                Não              Não
#
#   in_sala_acompanhante in_mobiliario_especifico in_material_especifico  \
# 0                  Não                      Não                    Não
# 1                  Não                      Não                    Não
# 2                  Não                      Não                    Não
# 3                  Não                      Não                    Não
# 4                  Não                      Não                    Não
#
#   in_nome_social no_municipio_prova sg_uf_prova     tp_presenca_cn  \
# 0            Não             Iguatu          CE     Faltou à prova
# 1            Não             Santos          SP  Presente na prova
# 2            Não            Socorro          SP  Presente na prova
# 3            Não       Praia Grande          SP  Presente na prova
# 4            Não           Curitiba          PR  Presente na prova
#
#       tp_presenca_ch     tp_presenca_lc     tp_presenca_mt tp_lingua  \
# 0     Faltou à prova     Faltou à prova     Faltou à prova  Espanhol
# 1  Presente na prova  Presente na prova  Presente na prova    Inglês
# 2  Presente na prova  Presente na prova  Presente na prova  Espanhol
# 3  Presente na prova  Presente na prova  Presente na prova    Inglês
# 4  Presente na prova  Presente na prova  Presente na prova    Inglês
#
#   tp_status_redacao                                               q001  \
# 0               NaN  Completou a 8ª série/9º ano do Ensino Fundamen...
# 1     Sem problemas  Completou o Ensino Médio, mas não completou a ...
# 2     Sem problemas  Completou a Faculdade, mas não completou a Pós...
# 3     Sem problemas  Completou a 8ª série/9º ano do Ensino Fundamen...
# 4     Sem problemas  Completou o Ensino Médio, mas não completou a ...
#
#                                                 q002  \
# 0  Completou a 8ª série/9º ano do Ensino Fundamen...
# 1  Completou o Ensino Médio, mas não completou a ...
# 2  Completou a Faculdade, mas não completou a Pós...
# 3  Completou o Ensino Médio, mas não completou a ...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
#
#                                                 q003  \
# 0  Grupo 4: Professor (de ensino fundamental ou m...
# 1  Grupo 2: Diarista, empregado doméstico, cuidad...
# 2  Grupo 2: Diarista, empregado doméstico, cuidad...
# 3  Grupo 2: Diarista, empregado doméstico, cuidad...
# 4  Grupo 3: Padeiro, cozinheiro industrial ou em ...
#
#                                                 q004  q005  \
# 0  Grupo 2: Diarista, empregado doméstico, cuidad...     4
# 1  Grupo 2: Diarista, empregado doméstico, cuidad...     4
# 2  Grupo 4: Professor (de ensino fundamental ou m...     4
# 3  Grupo 4: Professor (de ensino fundamental ou m...     5
# 4  Grupo 2: Diarista, empregado doméstico, cuidad...     4
#
#                               q006  q007        q008        q009      q010  \
# 0                   Até R$ 998,00.  Não.    Sim, um.  Sim, dois.      Não.
# 1  De R$ 4.990,01 até R$ 5.988,00.  Não.    Sim, um.  Sim, dois.      Não.
# 2  De R$ 4.990,01 até R$ 5.988,00.  Não.  Sim, dois.  Sim, três.  Sim, um.
# 3  De R$ 2.495,01 até R$ 2.994,00.  Não.    Sim, um.  Sim, dois.      Não.
# 4  De R$ 2.994,01 até R$ 3.992,00.  Não.    Sim, um.  Sim, dois.  Sim, um.
#
#        q011      q012      q013      q014  q015      q016  q017      q018  \
# 0  Sim, um.  Sim, um.      Não.      Não.  Não.      Não.  Não.      Não.
# 1      Não.  Sim, um.  Sim, um.  Sim, um.  Não.  Sim, um.  Não.      Não.
# 2      Não.  Sim, um.      Não.  Sim, um.  Não.  Sim, um.  Não.  Sim, um.
# 3      Não.  Sim, um.  Sim, um.      Não.  Não.  Sim, um.  Não.      Não.
# 4      Não.  Sim, um.  Sim, um.  Sim, um.  Não.  Sim, um.  Não.  Sim, um.
#
#          q019      q020      q021                  q022      q023        q024  \
# 0    Sim, um.  Sim, um.      Não.              Sim, um.      Não.    Sim, um.
# 1    Sim, um.      Não.  Sim, um.  Sim, quatro ou mais.  Sim, um.    Sim, um.
# 2  Sim, dois.      Não.      Não.  Sim, quatro ou mais.      Não.    Sim, um.
# 3  Sim, dois.      Não.  Sim, um.            Sim, dois.  Sim, um.    Sim, um.
# 4    Sim, um.      Não.  Sim, um.              Sim, um.  Sim, um.  Sim, dois.
#
#   q025
# 0  Sim
# 1  Sim
# 2  Sim
# 3  Sim
# 4  Sim

# %%
df = df.drop(columns='co_escola')

# %%
obj_columns = df.select_dtypes('object').columns
df[obj_columns] = df[obj_columns].astype('category')

# %%
df['nu_idade'] = df['nu_idade'].fillna(19.0) # mediana dos dados de treino

# %%
cat_columns = df.select_dtypes('category').columns
for cat in cat_columns:
    try:
        df[cat] = df[cat].cat.add_categories('Não informado')
    except ValueError:
        pass
    df[cat] = df[cat].fillna('Não informado')
df.columns[df.isna().sum() > 0]
# Out:
# Index([], dtype='object')

# %%
feature_columns = [
    'nu_idade', # unicas features numericas
    'q005', # unicas features numericas
    'sg_uf_residencia',
    'tp_sexo',
    'tp_cor_raca',
    'tp_st_conclusao',
    'tp_escola',
    'in_treineiro',
    'tp_dependencia_adm_esc',
    'tp_lingua',
    'q001',
    'q002',
    'q003',
    'q004',
    'q006',
    'q025'
]

# %%
df = pd.get_dummies(df, columns=feature_columns[2:], drop_first=True)
df.shape
# Out:
# (1783345, 186)

# %%
new_features = [
    "in_treineiro_Sim",
    "nu_idade",
    "q001_Completou a Faculdade, mas não completou a Pós-graduação.",
    "q001_Completou a Pós-graduação.",
    "q001_Completou o Ensino Médio, mas não completou a Faculdade.",
    "q001_Nunca estudou.",
    "q001_Não completou a 4ª série/5º ano do Ensino Fundamental.",
    "q001_Não sei.",
    "q002_Completou a Faculdade, mas não completou a Pós-graduação.",
    "q002_Completou a Pós-graduação.",
    "q002_Completou o Ensino Médio, mas não completou a Faculdade.",
    "q002_Nunca estudou.",
    "q002_Não completou a 4ª série/5º ano do Ensino Fundamental.",
    "q002_Não sei.",
    "q003_Grupo 2: Diarista, empregado doméstico, cuidador de idosos, babá, cozinheiro (em casas particulares), motorista particular, jardineiro, faxineiro de empresas e prédios, vigilante, porteiro, carteiro, office-boy, vendedor, caixa, atendente de loja, auxiliar administrativo, recepcionista, servente de pedreiro, repositor de mercadoria.",
    "q003_Grupo 3: Padeiro, cozinheiro industrial ou em restaurantes, sapateiro, costureiro, joalheiro, torneiro mecânico, operador de máquinas, soldador, operário de fábrica, trabalhador da mineração, pedreiro, pintor, eletricista, encanador, motorista, caminhoneiro, taxista.",
    "q003_Grupo 4: Professor (de ensino fundamental ou médio, idioma, música, artes etc.), técnico (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corretor de imóveis, supervisor, gerente, mestre de obras, pastor, microempresário (proprietário de empresa com menos de 10 empregados), pequeno comerciante, pequeno proprietário de terras, trabalhador autônomo ou por conta própria.",
    "q003_Grupo 5: Médico, engenheiro, dentista, psicólogo, economista, advogado, juiz, promotor, defensor, delegado, tenente, capitão, coronel, professor universitário, diretor em empresas públicas ou privadas, político, proprietário de empresas com mais de 10 empregados.",
    "q003_Não sei.",
    "q004_Grupo 2: Diarista, empregado doméstico, cuidador de idosos, babá, cozinheiro (em casas particulares), motorista particular, jardineiro, faxineiro de empresas e prédios, vigilante, porteiro, carteiro, office-boy, vendedor, caixa, atendente de loja, auxiliar administrativo, recepcionista, servente de pedreiro, repositor de mercadoria.",
    "q004_Grupo 3: Padeiro, cozinheiro industrial ou em restaurantes, sapateiro, costureiro, joalheiro, torneiro mecânico, operador de máquinas, soldador, operário de fábrica, trabalhador da mineração, pedreiro, pintor, eletricista, encanador, motorista, caminhoneiro, taxista.",
    "q004_Grupo 4: Professor (de ensino fundamental ou médio, idioma, música, artes etc.), técnico (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corretor de imóveis, supervisor, gerente, mestre de obras, pastor, microempresário (proprietário de empresa com menos de 10 empregados), pequeno comerciante, pequeno proprietário de terras, trabalhador autônomo ou por conta própria.",
    "q004_Grupo 5: Médico, engenheiro, dentista, psicólogo, economista, advogado, juiz, promotor, defensor, delegado, tenente, capitão, coronel, professor universitário, diretor em empresas públicas ou privadas, político, proprietário de empresas com mais de 10 empregados.",
    "q004_Não sei.",
    "q005",
    "q006_De R$ 1.497,01 até R$ 1.996,00.",
    "q006_De R$ 1.996,01 até R$ 2.495,00.",
    "q006_De R$ 11.976,01 até R$ 14.970,00.",
    "q006_De R$ 14.970,01 até R$ 19.960,00.",
    "q006_De R$ 2.495,01 até R$ 2.994,00.",
    "q006_De R$ 2.994,01 até R$ 3.992,00.",
    "q006_De R$ 3.992,01 até R$ 4.990,00.",
    "q006_De R$ 4.990,01 até R$ 5.988,00.",
    "q006_De R$ 5.988,01 até R$ 6.986,00.",
    "q006_De R$ 6.986,01 até R$ 7.984,00.",
    "q006_De R$ 7.984,01 até R$ 8.982,00.",
    "q006_De R$ 8.982,01 até R$ 9.980,00.",
    "q006_De R$ 9.980,01 até R$ 11.976,00.",
    "q006_De R$ 998,01 até R$ 1.497,00.",
    "q006_Mais de R$ 19.960,00.",
    "q006_Nenhuma renda.",
    "q025_Sim",
    "tp_cor_raca_Branca",
    "tp_cor_raca_Indígena",
    "tp_cor_raca_Não declarado",
    "tp_cor_raca_Preta",
    "tp_dependencia_adm_esc_Federal",
    "tp_dependencia_adm_esc_Privada",
    "tp_escola_Privada",
    "tp_escola_Pública",
    "tp_lingua_Inglês",
    "tp_sexo_Masculino",
    "tp_st_conclusao_Já concluí o Ensino Médio",
    "tp_st_conclusao_Não concluí e não estou cursando o Ensino Médio"
]
len(new_features)
# Out:
# 54

# %%
df[new_features].to_csv('data/prep_test.csv', index=False)
